# %%
from __future__ import division

import numpy as np
import scipy as sp
import skimage
import skimage.color
import skimage.exposure
import skimage.io
import SimpleCV
import cv2
import statsmodels.distributions
# Out:
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/SimpleCV-1.3-py2.7.egg/SimpleCV/base.py:42: UserWarning: Module argparse was already imported from /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/argparse.pyc, but /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import load_entry_point

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16.0, 8.0)

# %% [markdown]
# # Basics

# %% [markdown]
# ## Loading images

# %%
# scipy
img1 = sp.misc.imread( 'sv650.jpg' )
img1 = img1.astype(float).mean( axis=2 )

# scikits image
img2 = skimage.io.imread( 'sv650.jpg', as_grey=True )

# scikits color image
img2c = skimage.io.imread( 'sv650.jpg' )

# %%
print type( img1 )
print type( img2 )
# Out:
# <type 'numpy.ndarray'>
# <class 'skimage.io._io.Image'>

# %%
# values are floating point in range [0,1]
# this is because we converted to greyscale
print img1.dtype
print img2.dtype
print img2c.dtype
# Out:
# float64
# float64
# uint8

# %% [markdown]
# ## Displaying

# %%
plt.subplot( 1, 2, 1 )
plt.imshow( img2 )
plt.gray()

# %% [markdown]
# ## Basic image properties

# %%
print img2.shape
# ( height, width, n channels )
# Out:
# (470, 640)

# %%
print img2[:6,:6]
print ( 255 * img2[:6,:6] ).round()
# Out:
# [[ 0.14738     0.16752353  0.14621922  0.23663843  0.20237804  0.53534627]
#  [ 0.13671647  0.20897922  0.22800667  0.3150698   0.16683098  0.3437549 ]
#  [ 0.09720314  0.16974863  0.22351961  0.15372     0.21136     0.59446745]
#  [ 0.17253137  0.21624196  0.28037882  0.11930392  0.35816235  0.81130745]
#  [ 0.18204902  0.2117549   0.24116314  0.18401412  0.45763804  0.78474235]
#  [ 0.20391176  0.19804078  0.23055216  0.24175137  0.44649137  0.72178196]]
# [[  38.   43.   37.   60.   52.  137.]
#  [  35.   53.   58.   80.   43.   88.]
#  [  25.   43.   57.   39.   54.  152.]
#  [  44.   55.   71.   30.   91.  207.]
#  [  46.   54.   61.   47.  117.  200.]
#  [  52.   51.   59.   62.  114.  184.]]

# %%
print img2.min()
print img2.max()
print img2.mean()
# Out:
# 0.0
# 1.0
# 0.440814924067

# %%
aspect = float( img2.shape[1] ) / float( img2.shape[0] )
print aspect
# Out:
# 1.36170212766
